# %%
# 주석은 이렇게 하는거다
# 주석처리하고싶은 줄은 커서를 가져다 댄 후 "Ctrl(command) + /"를 누르면 그 줄은 주석처리된다
print("진짜 안보이는 거야?")
# pritn("Really")
print("Awesome!")
# Out:
# 진짜 안보이는 거야?
# Awesome!

# %%
'''
print("진짜 안보이는 거야?")
pritn("Really")
print("Awesome!")
'''

# %%
for animal in ("dog", "cat", "bird"):
    print(animal + " is cute")
# Out:
# dog is cute
# cat is cute
# bird is cute
