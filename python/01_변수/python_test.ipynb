# %% [markdown]
# #안녕하시오
# ##안녕하시오
# ###안녕하시오
#
# <strong>Mark Up 언어</strong>을 알아두면 좋다고하네요
# google colab 단축기도 알아두면 좋다고합디다.
#
#
# # 다음 코드 블럭 생성 : "Ctrl(command) + M B"
# # 현재 블럭 실행하기 : "Ctrl(command) + Enter"
# # 현재 블럭 실행하며 넘어가기 : "Ctrl(command) + Enter"
# # 실행하며 다음 코드블럭 생성하기 : "Alt(option) + Enter"

# %%
print("hello!")
# Out:
# hello!

# %%
print(2+3)
print(3*6)
# Out:
# 5
# 18
